# %%
import pandas as pd
import requests

# %% [markdown]
# ## 1번문제

# %%
subtotal= pd.read_csv("./subway/Subway_201601.csv",encoding = "cp949")
subtotal= subtotal[['역명','날짜', '구 분', '05 ~ 06', '06 ~ 07', '07 ~ 08', '08 ~ 09', '09 ~ 10', '10 ~ 11', '11 ~ 12', '12 ~ 13', '13 ~ 14', '14 ~ 15', '15 ~ 16', '16 ~ 17', '17 ~ 18', '18 ~ 19', '19 ~ 20', '20 ~ 21', '21 ~ 22', '22 ~ 23', '23 ~ 24', '00 ~ 01', '01 ~ 02']]
subtotal.columns = ['역명', '날짜', '구분', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02']
subtotal = subtotal.groupby(['역명','날짜','구분'], as_index=False).sum()

# %%
subtotal
# Out:
#              역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  \
# 0     가락시장(340)  2016-01-01  승차     72    102     78    145    165    173
# 1     가락시장(340)  2016-01-01  하차      6     81     65    116    121    143
# 2     가락시장(340)  2016-01-02  승차     45     66    113    288    341    334
# 3     가락시장(340)  2016-01-02  하차     11     81     83    181    224    195
# 4     가락시장(340)  2016-01-03  승차     47     72     81    198    252    256
# ...         ...         ...  ..    ...    ...    ...    ...    ...    ...
# 7373    회현(425)  2016-01-29  하차     36   1310   2647   6638   4688   2749
# 7374    회현(425)  2016-01-30  승차    102    151    175    304    506    683
# 7375    회현(425)  2016-01-30  하차     22    878    983   1963   3029   2896
# 7376    회현(425)  2016-01-31  승차     60     94     94    178    267    371
# 7377    회현(425)  2016-01-31  하차      7    206    349    698   1426   1080
#
#       11~12  ...  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24  \
# ...

# %%
for i in range(2,13):
    if i < 10:
        subcopy = pd.read_csv("./subway/Subway_2016{}.csv".format("0"+str(i)),encoding = "cp949")
        if i < 6 :
            subcopy= subcopy[['역명','날짜','구 분','05 ~ 06','06 ~ 07','07 ~ 08','08 ~ 09','09 ~ 10','10 ~ 11','11 ~ 12','12 ~ 13','13 ~ 14','14 ~ 15','15 ~ 16','16 ~ 17','17 ~ 18','18 ~ 19','19 ~ 20','20 ~ 21','21 ~ 22','22 ~ 23','23 ~ 24','00 ~ 01','01 ~ 02']]
            subcopy.columns = ['역명','날짜','구분','05~06','06~07','07~08','08~09','09~10','10~11','11~12','12~13','13~14','14~15','15~16','16~17','17~18','18~19','19~20','20~21','21~22','22~23','23~24','00~01','01~02']
            subcopy = subcopy.groupby(['역명','날짜','구분'],as_index = False).sum()
            subtotal = pd.concat([subtotal, subcopy])
        else:
            subcopy.columns = ['역명','날짜','구분','05~06','06~07','07~08','08~09','09~10','10~11','11~12','12~13','13~14','14~15','15~16','16~17','17~18','18~19','19~20','20~21','21~22','22~23','23~24','00~01','01~02']
            subcopy = subcopy.groupby(['역명','날짜','구분'],as_index = False).sum()
            subtotal = pd.concat([subtotal, subcopy])
    else:
        subcopy = pd.read_csv("./subway/Subway_2016{}.csv".format(str(i)),encoding = "cp949")
        subcopy.columns = ['역명','날짜','구분','05~06','06~07','07~08','08~09','09~10','10~11','11~12','12~13','13~14','14~15','15~16','16~17','17~18','18~19','19~20','20~21','21~22','22~23','23~24','00~01','01~02']
        subcopy = subcopy.groupby(['역명','날짜','구분'],as_index = False).sum()
        subtotal = pd.concat([subtotal,subcopy])

# %%
subtotal
# Out:
#              역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  \
# 0     가락시장(340)  2016-01-01  승차     72    102     78    145    165    173
# 1     가락시장(340)  2016-01-01  하차      6     81     65    116    121    143
# 2     가락시장(340)  2016-01-02  승차     45     66    113    288    341    334
# 3     가락시장(340)  2016-01-02  하차     11     81     83    181    224    195
# 4     가락시장(340)  2016-01-03  승차     47     72     81    198    252    256
# ...         ...         ...  ..    ...    ...    ...    ...    ...    ...
# 7373    회현(425)  2016-12-29  하차     38   1129   2677   6732   4198   2892
# 7374    회현(425)  2016-12-30  승차     84    155    251    360    641    817
# 7375    회현(425)  2016-12-30  하차     34   1080   2448   6273   3967   2573
# 7376    회현(425)  2016-12-31  승차     71    118    152    283    506    762
# 7377    회현(425)  2016-12-31  하차     26    427    698   1662   2479   2109
#
#       11~12  ...  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24  \
# ...

# %%
subtotal
# Out:
#              역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  \
# 0     가락시장(340)  2016-01-01  승차     72    102     78    145    165    173
# 1     가락시장(340)  2016-01-01  하차      6     81     65    116    121    143
# 2     가락시장(340)  2016-01-02  승차     45     66    113    288    341    334
# 3     가락시장(340)  2016-01-02  하차     11     81     83    181    224    195
# 4     가락시장(340)  2016-01-03  승차     47     72     81    198    252    256
# ...         ...         ...  ..    ...    ...    ...    ...    ...    ...
# 7373    회현(425)  2016-12-29  하차     38   1129   2677   6732   4198   2892
# 7374    회현(425)  2016-12-30  승차     84    155    251    360    641    817
# 7375    회현(425)  2016-12-30  하차     34   1080   2448   6273   3967   2573
# 7376    회현(425)  2016-12-31  승차     71    118    152    283    506    762
# 7377    회현(425)  2016-12-31  하차     26    427    698   1662   2479   2109
#
#       11~12  ...  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24  \
# ...

# %%
subway = subtotal.groupby(['역명','날짜','구분'], as_index = False).sum()

# %%
subway.head()
# Out:
#           역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  11~12  \
# 0  가락시장(340)  2016-01-01  승차     72    102     78    145    165    173    226
# 1  가락시장(340)  2016-01-01  하차      6     81     65    116    121    143    167
# 2  가락시장(340)  2016-01-02  승차     45     66    113    288    341    334    463
# 3  가락시장(340)  2016-01-02  하차     11     81     83    181    224    195    310
# 4  가락시장(340)  2016-01-03  승차     47     72     81    198    252    256    277
#
#    ...  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24  00~01  01~02
# 0  ...    274    253    230    124    166    165    138     35      2      0
# 1  ...    232    237    206    181    151    134    153    151     15      0
# 2  ...    399    373    299    226    236    205    172     60      0      0
# 3  ...    417    523    393    346    268    269    234    202     28      0
# 4  ...    292    329    294    191    204    178    139     52      1      0
#
# [5 rows x 24 columns]

# %%
subway.shape
# Out:
# (87108, 24)

# %% [markdown]
# # 2번문제

# %%
mask = subtotal.groupby(['역명']).sum()

# %%
subtotal['역명'] = subtotal['역명'].apply(lambda x : x[:-5])

# %%
# mask33 = subdf_copy1['역명'].apply(lambda x : x == "종로3가")

# %%
subtotal['count'] = subtotal.iloc[::].sum(axis = 1)
# Out:
# C:\Users\1asds\AppData\Local\Temp/ipykernel_6804/2935914938.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   subtotal['count'] = subtotal.iloc[::].sum(axis = 1)

# %%
subtotal['count'] = pd.to_numeric(subtotal['count'])

# %%
subtotal_copy = subtotal.copy()

# %%
sub
# Out:
# 0    3378
# Name: count, dtype: int64

# %%
print(format(subtotal_copy['count'][0][:1],","))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6804/2375948036.py in <module>
# ----> 1 print(format(subtotal_copy['count'][0][:1],","))
#
# TypeError: unsupported format string passed to Series.__format__

# %%
subtotal['count']
# Out:
# 0        3378
# 1        2931
# 2        5415
# 3        5138
# 4        4246
#         ...
# 7373    36134
# 7374    33945
# 7375    35480
# 7376    28633
# 7377    28188
# Name: count, Length: 87108, dtype: int64

# %%
subtotal.head(5)
# Out:
#      역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  11~12  ...  \
# 0  가락시장  2016-01-01  승차     72    102     78    145    165    173    226  ...
# 1  가락시장  2016-01-01  하차      6     81     65    116    121    143    167  ...
# 2  가락시장  2016-01-02  승차     45     66    113    288    341    334    463  ...
# 3  가락시장  2016-01-02  하차     11     81     83    181    224    195    310  ...
# 4  가락시장  2016-01-03  승차     47     72     81    198    252    256    277  ...
#
#    17~18  18~19  19~20  20~21  21~22  22~23  23~24  00~01  01~02  count
# 0    253    230    124    166    165    138     35      2      0   3378
# 1    237    206    181    151    134    153    151     15      0   2931
# 2    373    299    226    236    205    172     60      0      0   5415
# 3    523    393    346    268    269    234    202     28      0   5138
# 4    329    294    191    204    178    139     52      1      0   4246
#
# [5 rows x 25 columns]

# %%
mask = subtotal.groupby(['역명'])[['역명','count']].sum()

# %%
mask
# Out:
#          count
# 역명
# 가락시장   6592770
# 강남    72989920
# 강변    36523673
# 건대입구  34947918
# 경복궁   19243308
# ...        ...
# 합정    24807004
# 혜화    32442475
# 홍대입구  57959028
# 홍제    14563405
# 회현    22568162
#
# [110 rows x 1 columns]

# %% [markdown]
# ## 3번DataFrame에서 강남역만 추출하여 새로운 DataFrame 생성

# %%
gangnamMask = subtotal["역명"] == '강남'

# %%
subtotal[gangnamMask]
# Out:
#      역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  11~12  ...  \
# 62   강남  2016-01-01  승차   1381   1133    671    677    699    932   1048  ...
# 63   강남  2016-01-01  하차    174    757    765   1201   1984   1741   1836  ...
# 64   강남  2016-01-02  승차    516    698    646    903   1341   1732   2269  ...
# 65   강남  2016-01-02  하차    250    829   1137   2684   4896   4152   3920  ...
# 66   강남  2016-01-03  승차    734    711    590    703   1076   1092   1503  ...
# ..   ..         ...  ..    ...    ...    ...    ...    ...    ...    ...  ...
# 119  강남  2016-12-29  하차    451   1949   6162  14241  12364   6367   5733  ...
# 120  강남  2016-12-30  승차    627    851   1705   2653   2046   2170   3190  ...
# 121  강남  2016-12-30  하차    465   1889   5157  13479  10668   6446   5433  ...
# 122  강남  2016-12-31  승차   1156   1011    744   1050   1246   1732   2533  ...
# 123  강남  2016-12-31  하차    279   1017   1233   2636   5433   4415   4576  ...
#
# ...

# %%
# subtotal['역명'] = subdf_copy['역명'].apply(lambda x : x[:-5])

# %%
subtotal_gangnam = subtotal['역명'].apply(lambda x : x == '강남')

# %%
subgangnam = subtotal[subtotal_gangnam]

# %%
type(subgangnam)
# Out:
# pandas.core.frame.DataFrame

# %%
subgangnam
# Out:
#      역명          날짜  구분  05~06  06~07  07~08  08~09  09~10  10~11  11~12  ...  \
# 62   강남  2016-01-01  승차   1381   1133    671    677    699    932   1048  ...
# 63   강남  2016-01-01  하차    174    757    765   1201   1984   1741   1836  ...
# 64   강남  2016-01-02  승차    516    698    646    903   1341   1732   2269  ...
# 65   강남  2016-01-02  하차    250    829   1137   2684   4896   4152   3920  ...
# 66   강남  2016-01-03  승차    734    711    590    703   1076   1092   1503  ...
# ..   ..         ...  ..    ...    ...    ...    ...    ...    ...    ...  ...
# 119  강남  2016-12-29  하차    451   1949   6162  14241  12364   6367   5733  ...
# 120  강남  2016-12-30  승차    627    851   1705   2653   2046   2170   3190  ...
# 121  강남  2016-12-30  하차    465   1889   5157  13479  10668   6446   5433  ...
# 122  강남  2016-12-31  승차   1156   1011    744   1050   1246   1732   2533  ...
# 123  강남  2016-12-31  하차    279   1017   1233   2636   5433   4415   4576  ...
#
# ...

# %%
subgangnam['월'] = subgangnam['날짜'].apply(lambda x : x[:7])
# Out:
# C:\Users\1asds\AppData\Local\Temp/ipykernel_6804/1499983857.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subgangnam['월'] = subgangnam['날짜'].apply(lambda x : x[:7])

# %%
gangnamTotal = subgangnam.groupby(['월']).sum()

# %%
gangnamTotal
# Out:
#          05~06   06~07   07~08   08~09   09~10   10~11   11~12   12~13  \
# 월
# 2016-01  30688   96142  248023  452633  452117  272407  280048  309447
# 2016-02  26341   81838  215295  388182  382820  233906  238445  267631
# 2016-03  29912   96401  272901  472917  428080  257963  245185  263924
# 2016-04  29277   91237  237741  432805  401148  245302  230894  253786
# 2016-05  31472   94893  236848  439614  395280  242650  234098  254314
# 2016-06  30463   95618  238381  437429  400581  238476  232159  250864
# 2016-07  31150  103760  245736  460381  471990  281334  287233  320706
# 2016-08  29540   95131  236381  444226  428565  262546  264286  289856
# 2016-09  26719   82176  212991  390194  363317  220007  212504  234621
# 2016-10  29379   88972  220838  412845  396363  240666  232135  255853
# 2016-11  27995   87867  222572  434453  407457  237819  225710  246627
# 2016-12  31910   86947  209911  431968  402138  249033  251604  273746
#
# ...

# %%
gangnamTotal.index.name = ""

# %%
gangnamTotal
# Out:
#          05~06   06~07   07~08   08~09   09~10   10~11   11~12   12~13  \
#
# 2016-01  30688   96142  248023  452633  452117  272407  280048  309447
# 2016-02  26341   81838  215295  388182  382820  233906  238445  267631
# 2016-03  29912   96401  272901  472917  428080  257963  245185  263924
# 2016-04  29277   91237  237741  432805  401148  245302  230894  253786
# 2016-05  31472   94893  236848  439614  395280  242650  234098  254314
# 2016-06  30463   95618  238381  437429  400581  238476  232159  250864
# 2016-07  31150  103760  245736  460381  471990  281334  287233  320706
# 2016-08  29540   95131  236381  444226  428565  262546  264286  289856
# 2016-09  26719   82176  212991  390194  363317  220007  212504  234621
# 2016-10  29379   88972  220838  412845  396363  240666  232135  255853
# 2016-11  27995   87867  222572  434453  407457  237819  225710  246627
# 2016-12  31910   86947  209911  431968  402138  249033  251604  273746
#
# ...

# %%
gangnamTotal.loc[:,'count']
# Out:
# 2016-01    6565737
# 2016-02    5755230
# 2016-03    6308157
# 2016-04    5856535
# 2016-05    5919827
# 2016-06    5826363
# 2016-07    6788786
# 2016-08    6355968
# 2016-09    5460894
# 2016-10    5851270
# 2016-11    5929904
# 2016-12    6371249
# Name: count, dtype: int64

# %%
sub_one= gangnamTotal.loc[:,'count']

# %%
sub_one
# Out:
# 2016-01    6565737
# 2016-02    5755230
# 2016-03    6308157
# 2016-04    5856535
# 2016-05    5919827
# 2016-06    5826363
# 2016-07    6788786
# 2016-08    6355968
# 2016-09    5460894
# 2016-10    5851270
# 2016-11    5929904
# 2016-12    6371249
# Name: count, dtype: int64

# %% [markdown]
# ## 4번문제

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc

# %%
font_path = "./data/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize=(15,5))

plt.ylim(0, 7000000)
plt.bar(sub_one.index, sub_one.values)
plt.yscale()
plt.xticks(rotation = 45)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6804/238461708.py in <module>
#       3 plt.ylim(0, 7000000)
#       4 plt.bar(sub_one.index, sub_one.values)
# ----> 5 plt.yscale()
#       6 plt.xticks(rotation = 45)
#       7 plot.show()
#
# TypeError: yscale() missing 1 required positional argument: 'value'

# %%
sub_one.values
# Out:
# array([6565737, 5755230, 6308157, 5856535, 5919827, 5826363, 6788786,
#        6355968, 5460894, 5851270, 5929904, 6371249], dtype=int64)
